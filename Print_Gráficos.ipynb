# %% [markdown]
# <a href="https://colab.research.google.com/github/Joeljrbeginner/Storytelling-Dashboard-and-Tableau/blob/main/Print_Gr%C3%A1ficos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![graf 001.PNG](data:image/png;base64,...)
